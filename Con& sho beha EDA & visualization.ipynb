# %% [markdown]
#   #                 **DATA ANALYTICS - FINAL PROJECT**

# %% [markdown]
#   #### ✅ **PROJECT TITLE**

# %% [markdown]
# ## **🛍️  CONSUMER BEHAVIOUR AND SHOPPING HABITS - PYTHON DATA ANALYSIS PROJECT**

# %% [markdown]
# In today’s highly competitive and customer-driven market, understanding consumer behaviour is not just valuable — it's essential. This project analyzes consumer behaviour and shopping habits to uncover how people shop, what they buy, and why they make purchasing decisions. By examining demographics, product preferences, promotional effectiveness, customer engagement, and purchase patterns, the analysis provides valuable insights that help businesses segment their customers, personalize marketing efforts, and predict future behaviour. The relevance of this project lies in its ability to turn raw consumer data into actionable intelligence, enabling organizations to make informed, data-driven decisions that improve customer satisfaction, optimize sales strategies, and drive sustainable business growth in an increasingly competitive market.

# %% [markdown]
# #### ✅ **PROJECT OBJECTIVE**

# %% [markdown]
# **This project aims to analyze several key aspects of consumer data to understand how people shop, what they buy, and why.
# It includes:**
#
# 🧑‍🤝‍🧑Demographic analysis
#
# 🛒 Product preference and purchase behavior
#
# 📣 Promotion effectiveness
#
# 💬 Customer engagement
#
# 🧺 Market basket analysis
#
# **These analyses will support:**
#
# 1) Customer segmentation
#
# 2) Predicting future behavior
#
# 3) Making data-driven business decisions

# %% [markdown]
# #### **🗂️ Project Scope**

# %% [markdown]
#
# **This project will cover:**
#
# 1) Data cleaning and preprocessing
#
# 2) Exploratory data analysis (EDA)
#
# 3) Visualizations for key insights
#
# 4) Insight generation

# %% [markdown]
# #### **About Dataset**

# %% [markdown]
# This Dataset is from **Kaggle**. It consists of 3900 rows and 18 columns.
# **Dataset Glossary (Column-wise)**
# **Customer ID**:A unique identifier assigned to each individual customer, facilitating tracking and analysis of their shopping behaviour over time.
#
# **Age**: The age of the customer, providing demographic information for segmentation and targeted marketing strategies.
#
# **Gender**: The gender identification of the customer, a key demographic variable influencing product preferences and purchasing patterns.
#
# **Item Purchased**: The specific product or item selected by the customer during the transaction.
#
# **Category**: The broad classification or group to which the purchased item belongs (e.g., clothing, electronics, groceries).
#
# **Purchase Amount (USD)**: The monetary value of the transaction, denoted in United States Dollars (USD), indicates the cost of the purchased item(s).
#
# **Location**: The geographical location where the purchase was made, offering insights into regional preferences and market trends.
#
# **Size**: The size specification (if applicable) of the purchased item, relevant for apparel, footwear, and certain consumer goods.
#
# **Color**: The color variant or choice associated with the purchased item, influencing customer preferences and product availability.
#
# **Season**: The seasonal relevance of the purchased item (e.g., spring, summer, fall, winter), impacting inventory management and marketing strategies.
#
# **Review Rating**: A numerical or qualitative assessment provided by the customer regarding their satisfaction with the purchased item.
#
# **Subscription Status**: Indicates whether the customer has opted for a subscription service, offering insights into their level of loyalty and potential for recurring revenue.
#
# **Shipping Type**: Specifies the method used to deliver the purchased item (e.g., standard shipping, express delivery), influencing delivery times and costs.
#
# **Discount Applied**: Indicates if any promotional discounts were applied to the purchase, shedding light on price sensitivity and promotion effectiveness.
#
# **Promo Code Used**: Notes whether a promotional code or coupon was utilized during the transaction, aiding in the evaluation of marketing campaign success.
#
# **Previous Purchases**: Provides information on the number or frequency of prior purchases made by the customer, contributing to customer segmentation and retention strategies.
#
# **Payment Method**: Specifies the mode of payment employed by the customer (e.g., credit card, cash), offering insights into preferred payment options.
#
# **Frequency of Purchases**: Indicates how often the customer engages in purchasing activities, a critical metric for assessing customer loyalty and lifetime value.

# %% [markdown]
# ### **DATA CLEANING AND PRE-PROCESSING**

# %% [markdown]
# 📦 **Step 1: Import Libraries & Load Dataset**

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\resmi\Downloads\shopping_behavior_updated.csv")

# %% [markdown]
# 📘**Note: We start by importing common data analysis and visualization libraries. Then we load the CSV file into a DataFrame using pandas.**

# %%
df
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 0                        53       Kentucky    L       Gray  Winter
# 1                        64          Maine    L     Maroon  Winter
# ...

# %% [markdown]
# 🔍 **Step 2: Understand the Dataset**

# %%
df.head(10)
# Out:
#    Customer ID  Age Gender Item Purchased     Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse     Clothing                     53
# 1            2   19   Male        Sweater     Clothing                     64
# 2            3   50   Male          Jeans     Clothing                     73
# 3            4   21   Male        Sandals     Footwear                     90
# 4            5   45   Male         Blouse     Clothing                     49
# 5            6   46   Male       Sneakers     Footwear                     20
# 6            7   63   Male          Shirt     Clothing                     85
# 7            8   27   Male         Shorts     Clothing                     34
# 8            9   26   Male           Coat    Outerwear                     97
# 9           10   57   Male        Handbag  Accessories                     31
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# ...

# %% [markdown]
# **🔵head() gives us the first few rows of our dataset. here 10 numbers**

# %%
df.tail(5)
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)    Location Size      Color  Season  \
# 3895                     28    Virginia    L  Turquoise  Summer
# 3896                     49        Iowa    L      White  Spring
# 3897                     33  New Jersey    L      Green  Spring
# 3898                     77   Minnesota    S      Brown  Summer
# 3899                     81  California    M      Beige  Spring
#
#       Review Rating Subscription Status   Shipping Type Discount Applied  \
# 3895            4.2                  No  2-Day Shipping               No
# 3896            4.5                  No    Store Pickup               No
# ...

# %% [markdown]
# **🔵tail() gives us last few rows of our dataset. here last 5 numbers**

# %%
df.describe()
# Out:
#        Customer ID          Age  Purchase Amount (USD)  Review Rating  \
# count  3900.000000  3900.000000            3900.000000    3900.000000
# mean   1950.500000    44.068462              59.764359       3.749949
# std    1125.977353    15.207589              23.685392       0.716223
# min       1.000000    18.000000              20.000000       2.500000
# 25%     975.750000    31.000000              39.000000       3.100000
# 50%    1950.500000    44.000000              60.000000       3.700000
# 75%    2925.250000    57.000000              81.000000       4.400000
# max    3900.000000    70.000000             100.000000       5.000000
#
#        Previous Purchases
# count         3900.000000
# mean            25.351538
# std             14.447125
# min              1.000000
# 25%             13.000000
# 50%             25.000000
# 75%             38.000000
# max             50.000000

# %% [markdown]
# **🔵describe() provides a statistical summary of the numerical columns in our dataset.**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Customer ID             3900 non-null   int64
#  1   Age                     3900 non-null   int64
#  2   Gender                  3900 non-null   object
#  3   Item Purchased          3900 non-null   object
#  4   Category                3900 non-null   object
#  5   Purchase Amount (USD)   3900 non-null   int64
#  6   Location                3900 non-null   object
#  7   Size                    3900 non-null   object
#  8   Color                   3900 non-null   object
#  9   Season                  3900 non-null   object
#  10  Review Rating           3900 non-null   float64
#  11  Subscription Status     3900 non-null   object
#  12  Shipping Type           3900 non-null   object
#  13  Discount Applied        3900 non-null   object
# ...

# %% [markdown]
# **🔵info() will tells us dataset informations like the shape (rows, columns), the data type of our features, and the memory usage.**

# %%
df.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Shipping Type',
#        'Discount Applied', 'Promo Code Used', 'Previous Purchases',
#        'Payment Method', 'Frequency of Purchases'],
#       dtype='object')

# %% [markdown]
# **🔵columns returns the column names of our dataset**

# %%
df.dtypes
# Out:
# Customer ID                 int64
# Age                         int64
# Gender                     object
# Item Purchased             object
# Category                   object
# Purchase Amount (USD)       int64
# Location                   object
# Size                       object
# Color                      object
# Season                     object
# Review Rating             float64
# Subscription Status        object
# Shipping Type              object
# Discount Applied           object
# Promo Code Used            object
# Previous Purchases          int64
# Payment Method             object
# Frequency of Purchases     object
# dtype: object

# %% [markdown]
# **🔵dtypes return the dtypes in the DataFrame.**

# %% [markdown]
# 📘 **Note: All this helps  to get an overview of the dataset structure, including column names, data types, and summary statistics like mean and standard deviation.**

# %% [markdown]
# 🧼 **Step 3: Data Cleaning & Preprocessing**

# %%
df.isnull().sum()
# Out:
# Customer ID               0
# Age                       0
# Gender                    0
# Item Purchased            0
# Category                  0
# Purchase Amount (USD)     0
# Location                  0
# Size                      0
# Color                     0
# Season                    0
# Review Rating             0
# Subscription Status       0
# Shipping Type             0
# Discount Applied          0
# Promo Code Used           0
# Previous Purchases        0
# Payment Method            0
# Frequency of Purchases    0
# dtype: int64

# %% [markdown]
# **🔵isnull().sum()returns a Series that shows the number of missing (null) values in each column of a DataFrame.**

# %%
df.dropna(inplace =True)

# %% [markdown]
# **🔵dropna removes any null values in the dataset ,inplace=true modifies the original DataFrame directly**

# %%
df
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 0                        53       Kentucky    L       Gray  Winter
# 1                        64          Maine    L     Maroon  Winter
# ...

# %% [markdown]
# **🔵To check for duplicates**

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **🔵To remove duplicates**

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 0                        53       Kentucky    L       Gray  Winter
# 1                        64          Maine    L     Maroon  Winter
# ...

# %% [markdown]
# **🔵drop_duplicates removes duplcate rows in the dataset**

# %%
df = df.apply(lambda x: x.str.strip() if x.dtype == "object" else x)

# %%
df
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 0                        53       Kentucky    L       Gray  Winter
# 1                        64          Maine    L     Maroon  Winter
# ...

# %% [markdown]
# **📘 Note:Strips leading/trailing spaces from all string columns**

# %%
df['Gender']=df['Gender'].str.lower().str.capitalize()

# %%
df['Category']=df['Category'].str.lower().str.capitalize()

# %%
df
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 0                        53       Kentucky    L       Gray  Winter
# 1                        64          Maine    L     Maroon  Winter
# ...

# %% [markdown]
# **📘 Note:Standardize Categorical columns,here we cleaned inconsistent capitalization in "Gender" or "Category" columns**

# %%
df.rename(columns={'Purchase Amount (USD)':'Purchase Amount'},inplace=True)

# %%
df
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  Purchase Amount  \
# 0               1   55    Male         Blouse     Clothing               53
# 1               2   19    Male        Sweater     Clothing               64
# 2               3   50    Male          Jeans     Clothing               73
# 3               4   21    Male        Sandals     Footwear               90
# 4               5   45    Male         Blouse     Clothing               49
# ...           ...  ...     ...            ...          ...              ...
# 3895         3896   40  Female         Hoodie     Clothing               28
# 3896         3897   52  Female       Backpack  Accessories               49
# 3897         3898   46  Female           Belt  Accessories               33
# 3898         3899   44  Female          Shoes     Footwear               77
# 3899         3900   52  Female        Handbag  Accessories               81
#
# ...

# %% [markdown]
# **📘 Note: Renamed column name**

# %%
df['Purchase Amount']=df['Purchase Amount'].astype(float)

# %%
df
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  Purchase Amount  \
# 0               1   55    Male         Blouse     Clothing             53.0
# 1               2   19    Male        Sweater     Clothing             64.0
# 2               3   50    Male          Jeans     Clothing             73.0
# 3               4   21    Male        Sandals     Footwear             90.0
# 4               5   45    Male         Blouse     Clothing             49.0
# ...           ...  ...     ...            ...          ...              ...
# 3895         3896   40  Female         Hoodie     Clothing             28.0
# 3896         3897   52  Female       Backpack  Accessories             49.0
# 3897         3898   46  Female           Belt  Accessories             33.0
# 3898         3899   44  Female          Shoes     Footwear             77.0
# 3899         3900   52  Female        Handbag  Accessories             81.0
#
# ...

# %% [markdown]
# **🔵the datatype of column 'Purchase Amount' changed from int to float**

# %%
usd_to_inr = 83
df['Purchase Amount'] = df['Purchase Amount'] * usd_to_inr

# %%
df
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  Purchase Amount  \
# 0               1   55    Male         Blouse     Clothing           4399.0
# 1               2   19    Male        Sweater     Clothing           5312.0
# 2               3   50    Male          Jeans     Clothing           6059.0
# 3               4   21    Male        Sandals     Footwear           7470.0
# 4               5   45    Male         Blouse     Clothing           4067.0
# ...           ...  ...     ...            ...          ...              ...
# 3895         3896   40  Female         Hoodie     Clothing           2324.0
# 3896         3897   52  Female       Backpack  Accessories           4067.0
# 3897         3898   46  Female           Belt  Accessories           2739.0
# 3898         3899   44  Female          Shoes     Footwear           6391.0
# 3899         3900   52  Female        Handbag  Accessories           6723.0
#
# ...

# %% [markdown]
# **🔵Amount in USD converted to INR**

# %%
df.rename(columns={'Purchase Amount':'Purchase Amount (INR)'},inplace=True)

# %%
df
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (INR)       Location Size      Color  Season  \
# 0                    4399.0       Kentucky    L       Gray  Winter
# 1                    5312.0          Maine    L     Maroon  Winter
# ...

# %% [markdown]
# **🔵column Purchase Amount renamed to Purchase Amount (INR)**

# %%
columns = ['Age', 'Purchase Amount (INR)', 'Review Rating', 'Previous Purchases']
df[columns] = df[columns].apply(pd.to_numeric, errors='coerce')

# %% [markdown]
# **🔵selected columns to clean and ensured numeric types**

# %%
def remove_outliers_iqr(data, column):
    Q1 = data[column].quantile(0.25)
    Q3 = data[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
   
    return data[(data[column] >= lower_bound) & (data[column] <= upper_bound)]

# %% [markdown]
# **🔵now defined a function to remove outliers**

# %%
for i in columns:
    df = remove_outliers_iqr(df, i)

# %% [markdown]
# **🔵Applied the function to each column**

# %%
df.to_csv("cleaned_shopping_behaviour.csv", index=False)

# %% [markdown]
# **🔵saved the file**

# %%
df
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (INR)       Location Size      Color  Season  \
# 0                    4399.0       Kentucky    L       Gray  Winter
# 1                    5312.0          Maine    L     Maroon  Winter
# ...

# %% [markdown]
# **🔵added a new coulmn 'Age Group'**

# %%
df['Age Group'] = pd.cut(df['Age'], 
                         bins=[0, 12, 19, 35, 60, 120], 
                         labels=['Child','Teen', 'Young Adult', 'Adult', 'Senior'])

# %%
df
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (INR)       Location Size      Color  Season  \
# 0                    4399.0       Kentucky    L       Gray  Winter
# 1                    5312.0          Maine    L     Maroon  Winter
# ...

# %%
df_dummies = pd.get_dummies(df, columns=['Discount Applied'], drop_first=True)
df_dummies
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (INR)       Location Size      Color  Season  \
# 0                    4399.0       Kentucky    L       Gray  Winter
# 1                    5312.0          Maine    L     Maroon  Winter
# ...

# %% [markdown]
# **🔵using pd.get_dummies() converted categorical columns into true/false format**

# %% [markdown]
# #### 📊 **Exploratory Data Analysis (EDA) and visualisations**

# %% [markdown]
# **🔵created a new column 'Total Spent' as the product of Purchase Amount and Previous Purchases**

# %%
df['Total Spend'] = df['Purchase Amount (INR)'] * df['Previous Purchases']

# %%
df
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (INR)       Location Size      Color  Season  \
# 0                    4399.0       Kentucky    L       Gray  Winter
# 1                    5312.0          Maine    L     Maroon  Winter
# ...

# %% [markdown]
# 🔵**Added another  column with conditional logic**

# %%
df['High Spender'] = df['Purchase Amount (INR)'].apply(lambda x: 'Yes' if x > 5000 else 'No')

# %%
df
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (INR)       Location Size      Color  Season  ...  \
# 0                    4399.0       Kentucky    L       Gray  Winter  ...
# 1                    5312.0          Maine    L     Maroon  Winter  ...
# ...

# %% [markdown]
# 🔵**Created a new column 'Customer Segment' using multiple conditions**

# %%
df['Customer Segment'] = df.apply(lambda row: 
    'Loyal' if row['Previous Purchases'] > 10 else 
    'New' if row['Previous Purchases'] <= 2 else 
    'Returning', axis=1)

# %%
df
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (INR)       Location Size      Color  Season  ...  \
# 0                    4399.0       Kentucky    L       Gray  Winter  ...
# 1                    5312.0          Maine    L     Maroon  Winter  ...
# ...

# %% [markdown]
# ## UNIVARIATE ANALYSIS

# %% [markdown]
# #### 🔹 Numeric Features

# %%
numerical_cols = ['Age', 'Purchase Amount (INR)', 'Review Rating', 'Previous Purchases']

# %% [markdown]
# ## Distribution of numerical column(via histogram), Shape of the distribution (via KDE curve)

# %%
for col in numerical_cols:
    plt.figure(figsize=(8, 4))
    sns.histplot(df[col], bins=20, kde=True,color='yellowgreen')
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Count')
    plt.show();

# %% [markdown]
# **🔵univariate analysis for each numerical column using histograms with KDE (Kernel Density Estimation) overlays.**
# **output shows Distribution of numerical column(via histogram),
# Shape of the distribution (via KDE curve) and Helps identify skewness, outliers, or multimodal distributions**

# %% [markdown]
# ## Boxplot of numerical columns

# %%
numerical_cols = ['Age', 'Purchase Amount (INR)', 'Review Rating', 'Previous Purchases']

for col in numerical_cols:
     plt.figure(figsize=(6, 4))
     sns.boxplot(x=df[col])
     plt.title(f'Boxplot of {col}')
     plt.show()

# %% [markdown]
# #### 🔹 Categorical Features

# %% [markdown]
# ## Count plot of categorical columns

# %%
categorical_cols = ['Gender', 'Location' , 'Subscription Status', 'Discount Applied']

# %%
for col in categorical_cols:
    plt.figure(figsize=(8, 4))
    sns.countplot(data=df, x=col, order=df[col].value_counts().index)
    plt.title(f'Count Plot of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.xticks(rotation=45)
    plt.show()

# %% [markdown]
# ## Box Plot – Purchase Amount (INR)

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(x=df['Purchase Amount (INR)'], color='skyblue')
plt.title('Box Plot – Purchase Amount (INR)')
plt.xlabel('Purchase Amount (INR)')
plt.show()

# %% [markdown]
# **Based on the box plot of purchase amounts, here is a summary of the key statistics:**
#
# **✦Median: The line inside the box represents the median purchase amount, which is approximately ₹5,000. This means half of all purchases are below this amount and half are above.**
# **✦Interquartile Range (IQR): The box itself spans from the first quartile (Q1) to the third quartile (Q3). Q1 is around ₹3,500, and Q3 is about ₹6,500. This means that the middle 50% of all purchase amounts fall within this range, giving an IQR of ₹3,000.**
# **✦Range: The "whiskers" extending from the box indicate the overall range of the data, excluding any potential outliers. The plot shows that purchases generally range from approximately ₹1,500 to ₹8,500.**

# %% [markdown]
# ## BIVARIATE  & MULTIVARIATE ANALYSIS

# %% [markdown]
# ## Scatter plot of age and Total Spend

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Age', y='Total Spend', data=df)
plt.title('Total Spend vs Age')
plt.xlabel('Age')
plt.ylabel('Total Spend')
plt.grid(True)
plt.show()

# %% [markdown]
# **Possible insights from the plot:**
# **✦Spending is quite spread out for all age groups — no strong correlation between age and total spend is visible.**
# **✦Some high-spend outliers exist across all ages, suggesting that high spending is not limited to a particular age bracket.**
# **✦The spread appears fairly consistent from ages 18 to 70.**

# %% [markdown]
# ## Correlation Heatmap of Numerical Features

# %%
numerical_cols = df.select_dtypes(include=['int64', 'float64'])
corr_matrix = numerical_cols.corr()

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap of Numerical Features')
plt.show()

# %% [markdown]
# **✦Strong Positive Correlation: Previous Purchases ↔ Total Spend → loyal customers spend more.**
# **✦Moderte Positive Correlation: Amount (INR) ↔ Total Spend → higher single purchase amounts increase total spending.**
# **✦Weak Correlation: Age and Review Rating ↔ Total Spend → demographic and satisfaction ratings have minimal impact.**
# **✦Key Insight: Spending patterns are driven more by purchase history than by age or review ratings.**

# %% [markdown]
# ## box plot of purchase amount by gender

# %%
plt.figure(figsize=(6, 4))
sns.boxplot(x='Gender', y='Purchase Amount (INR)', data=df,color='aqua')
plt.title('Purchase Amount by Gender')
plt.xlabel('Gender')
plt.ylabel('Purchase Amount (INR)')
plt.grid(True)
plt.show()

# %% [markdown]
# **✦Median purchase amount is similar for both males and females.**
# **✦Spread (IQR) is almost identical across genders.**
# **✦Range of purchase amounts is similar, with minimum around ₹1,700 and maximum around ₹8,300 for both genders.**
# **✦No extreme outliers are visible.**

# %% [markdown]
# ## count plot of gender vs discount applied

# %%
plt.figure(figsize=(8, 5))
sns.countplot(data=df, x='Gender', hue='Discount Applied')
plt.title('Gender vs Discount Applied')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.legend(title='Discount Applied')
plt.grid(True)
plt.show()

# %% [markdown]
# **✦This bar chart compares Gender with whether a Discount was applied or not.**
# **✦For Males, a higher count received discounts compared to those who did not.**
# **✦For Females, the number without discounts is noticeably higher than those with discounts.**
# **✦Overall, males are more likely to get discounts, while females are more likely to have no discount applied.**

# %% [markdown]
# ## Pie chart of total money spend on various categories

# %%
total_spend=df.groupby('Category')['Total Spend'].sum().reset_index()

# %%
total_spend
# Out:
#       Category  Total Spend
# 0  Accessories  157383521.0
# 1     Clothing  219643398.0
# 2     Footwear   75956869.0
# 3    Outerwear   38352972.0

# %%
plt.pie(total_spend['Total Spend'],labels=total_spend['Category'],autopct='%1.1f%%',startangle=140)
plt.title("Distribution of total spend on various categories")
plt.show();

# %% [markdown]
# **This pie chart shows the distribution of total spending across four product categories:**
# **✦Clothing has the highest spending share at 44.7%.**
# **✦Accessories come next with 32%.**
# **✦Footwear accounts for 15.5%.**
# **✦Outerwear has the smallest share at 7.8%.**
# **Inference:**
#     **✦Most spending is concentrated in clothing and accessories, while outerwear contributes the least to total expenditure.**

# %%
average_review_rating=df.groupby(['Item Purchased','Category'])['Review Rating'].mean().reset_index()
average_review_rating
# Out:
#    Item Purchased     Category  Review Rating
# 0        Backpack  Accessories       3.752448
# 1            Belt  Accessories       3.761491
# 2          Blouse     Clothing       3.683626
# 3           Boots     Footwear       3.812500
# 4            Coat    Outerwear       3.730435
# 5           Dress     Clothing       3.754819
# 6          Gloves  Accessories       3.864286
# 7         Handbag  Accessories       3.775163
# 8             Hat  Accessories       3.806494
# 9          Hoodie     Clothing       3.719205
# 10         Jacket    Outerwear       3.763190
# 11          Jeans     Clothing       3.648387
# 12        Jewelry  Accessories       3.756140
# 13          Pants     Clothing       3.718713
# 14        Sandals     Footwear       3.841250
# 15          Scarf  Accessories       3.700000
# 16          Shirt     Clothing       3.629586
# 17          Shoes     Footwear       3.747333
# 18         Shorts     Clothing       3.711465
# ...

# %% [markdown]
# ## Barplot of Average review rating  for different items purchased, segmented by category

# %%
plt.figure(figsize=(15,8))
sns.barplot(data=average_review_rating,x='Item Purchased',y='Review Rating',hue='Category')
plt.title("Average review rating  for different items purchased, segmented by category")
plt.show();

# %% [markdown]
# **✦Most items across all categories have ratings close to 3.7–3.9.**
# **✦Footwear items like Boots and Sandals tend to have slightly higher average ratings (~3.85–3.9).**
# **✦Clothing items such as Blouse, Jeans, and Scarf show slightly lower ratings (~3.65–3.75).**
# **✦Accessories (e.g., Backpack, Belt) maintain stable ratings around 3.75–3.85.**
# **✦Outerwear items (Coat, Jacket) are in the mid-range (~3.75–3.8).**
#
# **Inference: Ratings are fairly consistent, with minor variations. Footwear generally performs slightly better in customer satisfaction compared to some clothing items.**

# %% [markdown]
# ## Pie Chart for the share of purchases by Payment Method

# %%
payment_counts=df['Payment Method'].value_counts()
payment_counts
# Out:
# Payment Method
# PayPal           677
# Credit Card      671
# Cash             670
# Debit Card       636
# Venmo            634
# Bank Transfer    612
# Name: count, dtype: int64

# %%
plt.pie(payment_counts,labels=payment_counts.index,autopct='%1.1f%%',startangle=90)
plt.title("share of purchases by payment method")
plt.show()

# %% [markdown]
# **✦All payment methods are used fairly evenly, each making up about 15–17% of transactions.**
# **✦PayPal has the highest share at 17.4%, closely followed by Credit Card and Cash (both 17.2%).**
# **✦Debit Card and Venmo each account for 16.3%.**
# **✦Bank Transfer has the smallest share at 15.7%.**
# **Inference: There’s no single dominant payment method — customers show diverse preferences, with PayPal having a slight edge.**

# %% [markdown]
# ## scatterplot that shows Purchase Amount vs. Age by Gender

# %%
plt.figure(figsize=(15,6))
sns.scatterplot(data=df,x='Age',y='Purchase Amount (INR)',hue='Gender',s=150)
plt.title("Purchase Amount vs. Age by Gender")
plt.show();

# %% [markdown]
# **✦The dots represent individual purchases, with blue for males and orange for females.**
# **✦Purchases are spread across all ages from about 18 to 70 years.**
# **✦Purchase amounts range roughly from ₹1,500 to ₹8,500.**
# **Both males and females appear evenly distributed in all age and purchase ranges — no strong pattern of one gender spending more or less is evident.**
# **✦Inference: Spending behavior appears relatively consistent across genders and ages, without a dominant demographic making significantly higher purchases.**

# %% [markdown]
# ## Barplot of Average Purchase Amount per Category

# %%
average_purchase=df.groupby('Category')['Purchase Amount (INR)'].mean().reset_index()
average_purchase
# Out:
#       Category  Purchase Amount (INR)
# 0  Accessories            4966.612903
# 1     Clothing            4982.102476
# 2     Footwear            5001.200334
# 3    Outerwear            4745.345679

# %%
sns.barplot(data=average_purchase,x='Category',y='Purchase Amount (INR)',color='indianred')
plt.title("Average Purchase Amount per Category")
plt.show()

# %% [markdown]
# **This bar chart shows the average purchase amount per category in INR.**
# **Observations:**
# **✦All categories — Accessories, Clothing, Footwear, and Outerwear — have average purchase amounts close to ₹5,000.**
# **✦Footwear has the highest average (₹5,000), while Outerwear has the lowest (₹4,750).**
# **✦The difference between categories is small, indicating fairly consistent spending across product types.**
# **Inference:**
# **✦shoppers tend to spend almost the same amount regardless of product category, suggesting uniform pricing or balanced buying behavior across categories**

# %% [markdown]
# ## Grouped Bar Plot for Category vs. Age Group

# %%
plt.figure(figsize=(10, 6))
sns.countplot( data=df, x='Category', hue='Age Group')
plt.title('Category vs. Age Group')
plt.xlabel('Product Category')
plt.ylabel('Count')
plt.legend(title='Age Group')
plt.show()

# %% [markdown]
# **✦Clothing dominates across all age groups, especially for Adults (800+) and Young Adults (~540).**
# **✦Footwear sales are much lower overall, with Adults leading (~310).**
# **✦Outerwear has the least counts, again led by Adults (~160).**
# **✦Accessories are also popular, especially among Adults (~580) and Young Adults (~370).**
# **✦Children have minimal counts across all categories, possibly indicating either fewer purchases or smaller representation in the dataset.**

# %% [markdown]
# ## Violin Plot for Age vs. Purchase Amount, split by Gender

# %%
plt.figure(figsize=(10, 6))
sns.violinplot( data=df,x='Gender',y='Purchase Amount (INR)',hue='Gender')
plt.title('Distribution of Purchase Amount by Gender')
plt.xlabel('Gender')
plt.ylabel('Purchase Amount (INR)')
plt.show()

# %% [markdown]
# **✦No significant difference: The distribution of purchase amounts is very similar for both males and females.**
# **✦Similar median: The median purchase amount (indicated by the white line inside the box plot) is nearly identical for both genders.**
# **✦Comparable spread: The range of purchase amounts and the concentration of purchases (where the violin plot is widest) are similar for both male and female customers**
# **✦Purchasing behavior is alike: The chart suggests that gender does not appear to be a major factor influencing the amount of money spent on purchases.**

# %% [markdown]
# ## side-by-side violin plot (also called a grouped violin plot) showing the distribution of purchase amounts for each gender at different ages

# %%
plt.figure(figsize=(20, 10))
sns.violinplot( data=df,  x='Age',y='Purchase Amount (INR)',hue='Gender',palette='Set1')
plt.title('Age vs Purchase Amount by Gender')
plt.xlabel('Age')
plt.ylabel('Purchase Amount (INR)')
plt.legend(title='Gender')
plt.show()

# %% [markdown]
# **✦No strong correlation between age and spending: The plot shows that the distribution of purchase amounts is consistent across all age groups, suggesting that age is not a major factor in how much a customer spends.**
# **✦No gender difference: Within each age group, the spending patterns for males and females are very similar, with no significant differences in their purchase amount distributions.**
# **✦Conclusion: The data suggests that neither age nor gender appears to be a primary driver of purchase amount.**

# %% [markdown]
# ## Scatter Plot with Hue & Size – Purchase amount vs. Category, colored by Age Group, size by Previous Purchases

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot( data=df, x='Category', y='Purchase Amount (INR)',hue='Age Group', size='Previous Purchases')           
plt.title('Purchase Amount vs. Category (Color: Age Group, Size: Previous Purchases)')
plt.xlabel('Category')
plt.ylabel('Purchase Amount (INR)')
plt.show()

# %% [markdown]
# **The plot shows that purchase amount is not strongly related to the product category, the customer's age group, or the number of their previous purchases. The purchase amounts are widely distributed across all these variables without any clear patterns.**

# %% [markdown]
# ## Pairplot showing relationships between Age, Purchase Amount, and Review Rating, with colouring by Gender

# %%
cols = ["Age", "Purchase Amount (INR)", "Review Rating", "Gender"]
cols
# Out:
# ['Age', 'Purchase Amount (INR)', 'Review Rating', 'Gender']

# %%
sns.pairplot(df[cols],hue='Gender')
plt.suptitle('Pair Plot – Age, Purchase Amount, Review Rating by Gender',y=1.02)
plt.show()

# %% [markdown]
# **✦No strong correlations: There are no clear linear relationships between any of the variables. Age does not predict a customer's purchase amount or review rating, and the purchase amount does not correlate with the review rating.**
# **✦Similar distributions by gender: The distributions for males and females are largely the same across all three variables. This suggests that gender does not significantly impact age, purchase amount, or review rating.**
# **✦High review ratings: The distribution of review ratings is heavily concentrated between 4.0 and 5.0 for both genders, indicating a generally high level of customer satisfaction.**
# **✦Purchase amount and age are consistent: The data reinforces previous observations that purchase amounts are spread across all age groups and that neither variable is a strong predictor of the other.**

# %% [markdown]
# ## Barplot of High Spenders by Customer Segment

# %%
plt.figure(figsize=(8,5))
sns.barplot(x='Customer Segment', y='Purchase Amount (INR)', data=df, hue='High Spender', palette='cool')
plt.title("High Spenders by Customer Segment ")
plt.show()

# %% [markdown]
# **✦Based on the bar chart, the key inference is that the customer segment (Loyal, New, or Returning) has no impact on a customer's average purchase amount.**
# **✦Significant difference in spending: There is a stark difference in purchase amount between customers categorized as high spenders (purple bars) and those who are not (blue bars). High spenders consistently spend more than double the amount of non-high spenders**.
# **✦No difference across segments: The average purchase amount for high spenders is roughly the same across all three customer segments. Similarly, the average purchase amount for non-high spenders is also consistent across all segments.**
# **✦In summary, the most important factor in determining a high purchase amount is the high spender categorization, not the customer's loyalty status.**

# %%
avg_purchase_cus=df.groupby('Customer Segment')['Purchase Amount (INR)'].mean().reset_index()
avg_purchase_cus
# Out:
#   Customer Segment  Purchase Amount (INR)
# 0            Loyal            4941.563222
# 1              New            4924.845161
# 2        Returning            5062.736089

# %% [markdown]
# ## lineplot showing purchase amount trend across customer segment

# %%
sns.lineplot(data=avg_purchase_cus,x='Customer Segment',y='Purchase Amount (INR)',color='tomato')
plt.title("Average Purchase Amount per Customer Segment")
plt.show()

# %% [markdown]
# **Based on the line plot,**
# **✦The average purchase amount is highest for Returning customers, at approximately ₹5,060.**
# **✦The average amount for Loyal customers is slightly lower, around ₹4,940.**
# **✦The average amount for New customers is the lowest, at about ₹4,925.**
# **✦Overall, the trend shows that while the difference is small, returning customers spend the most on average, followed by loyal customers, with new customers spending the least.**

# %%
pivot_table = df.pivot_table( values='Purchase Amount (INR)', index='Age Group', columns='Gender',aggfunc='mean',observed=False )
pivot_table
# Out:
# Gender            Female         Male
# Age Group
# Teen         5066.531915  5004.980583
# Young Adult  5116.679348  4928.425157
# Adult        4872.031405  4972.880064
# Senior       5141.267544  4869.501010

# %%
plt.figure(figsize=(8,5))
sns.heatmap(pivot_table, annot=True,fmt=".2f", cmap='YlGnBu')
plt.title("Average Purchase Amount by Age Group & Gender", fontsize=14)
plt.ylabel("Age Group")
plt.xlabel("Gender")
plt.show()

# %% [markdown]
# **Based on the heat map, there are observable differences in average purchase amounts across age groups and genders.**
# **✦Gender Differences: On average, females spend more than males in the Teen, Young Adult, and Senior age groups. The largest spending gap is between senior females (₹5141.27) and senior males (₹4869.50), while the only exception is the Adult group where males spend slightly more.**
# **✦Spending by Age Group: The highest average purchase amounts are from senior females (₹5141.27) and young adult females (₹5116.68). The lowest average purchase amounts are from adult females (₹4872.03) and senior males (₹4869.50).**
# **In summary, the data suggests that while the overall range of spending is narrow, female customers tend to spend more than their male counterparts, especially in the senior and young adult categories.**

# %% [markdown]
# ## stacked bar plot Total Purchase Amount by Category & Payment Method

# %%
pivot_category_payment = df.pivot_table( values='Purchase Amount (INR)', index='Category',columns='Payment Method', aggfunc='sum')
pivot_category_payment
# Out:
# Payment Method  Bank Transfer       Cash  Credit Card  Debit Card     PayPal  \
# Category
# Accessories          880298.0  1069787.0    1098505.0   1010940.0  1146894.0
# Clothing            1426272.0  1479060.0    1555752.0   1455239.0  1395147.0
# Footwear             467622.0   512027.0     444133.0    515679.0   511280.0
# Outerwear            258960.0   259292.0     247340.0    233728.0   275726.0
#
# Payment Method      Venmo
# Category
# Accessories      952176.0
# Clothing        1342442.0
# Footwear         544978.0
# Outerwear        262446.0

# %%
pivot_category_payment.plot(kind='bar', stacked=True, figsize=(10,6))
plt.title("Total Purchase Amount by Category & Payment Method", fontsize=14)
plt.ylabel("Total Purchase Amount (INR)")
plt.xlabel("Category")
plt.legend(title="Payment Method")
plt.show()

# %% [markdown]
# **✦Category Popularity: The Clothing category has the highest total purchase amount, followed by Accessories. Footwear and Outerwear have significantly lower total purchase amounts.**
# **✦Payment Method Preference: The usage of payment methods appears to be consistent across all categories. The most significant portions of spending are consistently made using Venmo and Credit Card, followed by Debit Card and Cash.**
# **✦Less Preferred Methods: Bank Transfer and PayPal make up a smaller portion of the total spending in all categories.**
# **✦In summary, while there are clear differences in total spending between product categories, the customer's choice of payment method remains relatively stable regardless of what they are purchasing.**

# %% [markdown]
# **pivot_table: Summarizes total purchase amounts per location & payment method**

# %%
pivot_table = df.pivot_table(index='Location',columns='Payment Method',values='Purchase Amount (INR)',aggfunc='sum')
pivot_table
# Out:
# Payment Method  Bank Transfer      Cash  Credit Card  Debit Card    PayPal  \
# Location
# Alabama               53618.0   34113.0      89391.0     99351.0   74783.0
# Alaska                70882.0   34777.0      92296.0     51294.0   75281.0
# Arizona               47891.0   46314.0      71629.0     82253.0   69305.0
# Arkansas              73953.0  111967.0      52456.0     38678.0   73538.0
# California            32121.0   71297.0      91798.0     93126.0  106738.0
# Colorado              59843.0   57519.0      75198.0     55112.0   64740.0
# Connecticut           56357.0   81340.0      48970.0     46314.0   74949.0
# Delaware              62250.0   50796.0      43326.0     57685.0   80842.0
# Florida               45733.0   34777.0      70384.0     49136.0   66566.0
# Georgia               52954.0   62084.0     105493.0     62333.0   34694.0
# Hawaii                80510.0   55776.0      40670.0     60673.0   44405.0
# ...

# %% [markdown]
# ## Heatmap: Makes it easy to see which payment methods dominate in each location

# %%
plt.figure(figsize=(15,10))
sns.heatmap(pivot_table, annot=True,fmt=".0f",cmap="YlGnBu")
plt.title('Total Purchase Amount by Location & Payment Method', fontsize=14)
plt.xlabel('Payment Method')
plt.ylabel('Location')
plt.show()

# %% [markdown]
# **Based on the heat map, here are the key inferences about total purchase amount by location and payment method:**
# **✦Significant Variation in Spending: Total purchase amounts vary greatly depending on both the location (state) and the payment method used.**
# **Top-Spending States and Methods:**
# **✦Montana stands out with the highest total purchase amounts, particularly for Cash (₹128,152) and Credit Card (₹108,879).**
# **✦New Jersey, Connecticut, New York, Colorado, and Nevada are also high-spending states, with high totals frequently seen for PayPal and Cash transactions.**
# **Payment Method Preferences:**
# **✦Credit Card and PayPal are frequently used for the highest total purchase amounts across many states.**
# **✦Cash also accounts for some of the highest spending totals, suggesting it is a preferred method for significant purchases in certain locations.**
# **✦No Single Dominant Method: The chart shows that the preferred payment method for the highest spending is not universal and can be highly dependent on the location.**
